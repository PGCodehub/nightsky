# %%
# import os
# import sys
# sys.path.append('/root/nightsky/NightSky')

# %%
# from AgentGraph import AgenticGraph , MessageDict , StartNode , EndNode
# from typing import Any, Callable, Dict, List, Optional, Union, TypedDict, Tuple, Type, TypeVar
# from pydantic import BaseModel, Field
# import json

# %%
# def main():
#     class Logs(BaseModel):
#         id: str
#         question: str
#         docs: Optional[List[Any]] = None
#         answer: str
#         grade: Optional[int] = None
#         grader: Optional[str] = None
#         feedback: Optional[str] = None

#     class FailureAnalysisState(BaseModel):
#         docs: List[Logs]
#         failures: List[Logs] = Field(default_factory=list)
#         fa_summary: str = ""


#     def process_logs(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#         print("Processing logs...")
#         state = FailureAnalysisState(**graph_data)
#         state.failures = [log for log in state.docs if log.grade is not None and log.grade < 5]
#         metahistory = MessageDict(
#             role="system",
#             content="Processed logs",
#             result=len(state.failures),
#             create_agent_msg=True
#         )
#         return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

#     def analyze_failures(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#         print("Analyzing failures...")
#         state = FailureAnalysisState(**graph_data)
#         state.fa_summary = f"Found {len(state.failures)} failures out of {len(state.docs)} total logs."
#         metahistory = MessageDict(
#             role="assistant",
#             content=f"Analyzed failures: {state.fa_summary}",
#             result=state.fa_summary,
#             create_agent_msg=True
#         )
#         return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

#     # Initialize the graph with the FailureAnalysisState
#     initial_state = FailureAnalysisState(
#         docs=[
#             Logs(id='1', question='Q1', answer='A1', grade=4),
#             Logs(id='2', question='Q2', answer='A2', grade=7),
#             Logs(id='3', question='Q3', answer='A3', grade=3),
#         ]
#     )
#     graph = AgenticGraph(initial_state.dict(), chat_id="example_chat")
    
#     graph.add_node(StartNode())
#     graph.add_node("ProcessLogs", process_logs, is_agent=True)
#     graph.add_node("AnalyzeFailures", analyze_failures, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "ProcessLogs")
#     graph.add_edge("ProcessLogs", "AnalyzeFailures")
#     graph.add_edge("AnalyzeFailures", "End")

#     # Execute the graph
#     print("Executing the graph...")
#     graph.execute()

#     print("Final Graph Data:", graph.get_graph_data())
#     metahistory_dict, metahistory_order = graph.get_metahistory()
#     print("Metahistory entries:", metahistory_dict)
#     print("Metahistory order:", metahistory_order)

#     # Print agentic memory for each agent
#     for agent_id in graph.agent_ids:
#         print(f"Agentic Memory for agent {agent_id}:")
#         print(graph.get_agentic_memory(agent_id))

# if __name__ == "__main__":
#     main()

# %%
# import openai
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os

# openapi_key = "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"

# # Set up OpenAI client
# client = openai.OpenAI(api_key=openapi_key)


# class MessageDict(BaseModel):
#     role: str
#     content: str
#     result: Any = None
#     tool_call: bool = False
#     tool_args: Optional[Dict[str, Any]] = None
#     create_agent_msg: bool = True
#     node_index: Optional[Tuple[str, str, int]] = None

# class ProductAnalysis(BaseModel):
#     product_name: str
#     analysis: str

# class MarketingStrategy(BaseModel):
#     product_name: str
#     strategy: str

# class WorkflowState(BaseModel):
#     products: List[str]
#     analyses: List[ProductAnalysis] = Field(default_factory=list)
#     strategies: List[MarketingStrategy] = Field(default_factory=list)

# # Define agent functions
# def market_analyst(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As the Lead Market Analyst at a premier digital marketing firm, you specialize in dissecting online business landscapes. Your goal:
#     Conduct amazing analysis of the products and competitors, providing in-depth
#     insights to guide marketing strategies"""

#     for product in state.products:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Analyze the product: {product}"}
#             ]
#         )
        
#         analysis = response.choices[0].message.content
#         state.analyses.append(ProductAnalysis(product_name=product, analysis=analysis))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Analyzed {len(state.products)} products",
#         result=len(state.analyses),
#         create_agent_msg=True
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def marketing_strategist(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """You are the Chief Marketing Strategist at a leading digital marketing agency, known for crafting bespoke strategies that drive success. Your goal:
#     Synthesize amazing insights from product analysis to formulate incredible
#     marketing strategies."""

#     for analysis in state.analyses:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Create a marketing strategy based on this analysis: {analysis.analysis}"}
#             ]
#         )
        
#         strategy = response.choices[0].message.content
#         state.strategies.append(MarketingStrategy(product_name=analysis.product_name, strategy=strategy))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Created strategies for {len(state.analyses)} products",
#         result=len(state.strategies),
#         create_agent_msg=True
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# # Test function
# def test_marketing_workflow():
#     initial_state = WorkflowState(products=["Smartphone", "Laptop", "Smart Watch"])
    
#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")
    
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("MarketAnalyst", "MarketingStrategist")
#     graph.add_edge("MarketingStrategist", "End")

#     print("Executing the marketing workflow...")
#     graph.execute()

#     final_state = WorkflowState(**graph.get_graph_data())
#     print("\nFinal Workflow State:")
#     print(f"Products analyzed: {len(final_state.products)}")
#     print(f"Analyses created: {len(final_state.analyses)}")
#     print(f"Strategies developed: {len(final_state.strategies)}")

#     print("\nDetailed Results:")
#     for product, analysis, strategy in zip(final_state.products, final_state.analyses, final_state.strategies):
#         print(f"\nProduct: {product}")
#         print(f"Analysis summary: {analysis.analysis[:100]}...")
#         print(f"Strategy summary: {strategy.strategy[:100]}...")

#     print("\nAgent Memories:")
#     for agent_id in graph.agent_ids:
#         print(f"\nAgent {agent_id}:")
#         for message in graph.get_agentic_memory(agent_id):
#             print(f"- {message['role']}: {message['content'][:50]}...")

# if __name__ == "__main__":
#     test_marketing_workflow()

# %%
# import openai
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os

# # Set up OpenAI client
# openapi_key = "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"

# client = openai.OpenAI(api_key=openapi_key)

# class ProductAnalysis(BaseModel):
#     product_name: str
#     analysis: str
#     market_size: str
#     target_audience: str

# class MarketingStrategy(BaseModel):
#     product_name: str
#     strategy: str

# class WorkflowState(BaseModel):
#     products: List[str]
#     analyses: List[ProductAnalysis] = Field(default_factory=list)
#     strategies: List[MarketingStrategy] = Field(default_factory=list)

# # Define agent functions
# def market_analyst(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As the Lead Market Analyst at a premier digital marketing firm, you specialize in dissecting online business landscapes. Your goal:
#     Conduct amazing analysis of the products and competitors, providing in-depth
#     insights to guide marketing strategies. Include market size and target audience in your analysis."""

#     for product in state.products:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Analyze the product: {product}"}
#             ]
#         )
        
#         analysis = response.choices[0].message.content
        
#         # Extract market size and target audience from the analysis
#         market_size = "Large"  # Placeholder, you might want to extract this from the analysis
#         target_audience = "General consumers"  # Placeholder, you might want to extract this from the analysis
        
#         state.analyses.append(ProductAnalysis(
#             product_name=product,
#             analysis=analysis,
#             market_size=market_size,
#             target_audience=target_audience
#         ))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Analyzed {len(state.products)} products",
#         result=len(state.analyses),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def marketing_strategist(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """You are the Chief Marketing Strategist at a leading digital marketing agency, known for crafting bespoke strategies that drive success. Your goal:
#     Synthesize amazing insights from product analysis to formulate incredible
#     marketing strategies."""

#     for analysis in state.analyses:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Create a marketing strategy based on this analysis: {analysis.analysis}"}
#             ]
#         )
        
#         strategy = response.choices[0].message.content
#         state.strategies.append(MarketingStrategy(product_name=analysis.product_name, strategy=strategy))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Created strategies for {len(state.analyses)} products",
#         result=len(state.strategies),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def niche_market_specialist(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As a Niche Market Specialist, your expertise lies in tailoring strategies for products with smaller, highly specific target audiences. Your goal:
#     Refine the existing marketing strategies to better suit niche markets and specialized consumer groups."""

#     for analysis, strategy in zip(state.analyses, state.strategies):
#         if analysis.market_size == "Small" and "niche" in analysis.target_audience.lower():
#             response = client.chat.completions.create(
#                 model="gpt-3.5-turbo",
#                 messages=[
#                     {"role": "system", "content": system_prompt},
#                     {"role": "user", "content": f"Refine this strategy for a niche market:\nProduct: {analysis.product_name}\nAnalysis: {analysis.analysis}\nCurrent Strategy: {strategy.strategy}"}
#                 ]
#             )
            
#             refined_strategy = response.choices[0].message.content
#             strategy.strategy = refined_strategy

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Refined strategies for niche markets",
#         result=len([s for s in state.strategies if "niche" in s.strategy.lower()]),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# # Conditional function for branching
# def is_niche_market(graph_data: Dict[str, Any]) -> bool:
#     state = WorkflowState(**graph_data)
#     return any(analysis.market_size == "Small" and "niche" in analysis.target_audience.lower() for analysis in state.analyses)

# # Test function
# def test_marketing_workflow():
#     initial_state = WorkflowState(products=["Smartphone", "Custom Mechanical Keyboard", "Smart Watch"])
    
#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")
    
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     graph.add_node("NicheMarketSpecialist", niche_market_specialist, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("MarketAnalyst", "MarketingStrategist")
    
#     # Add branching edge
#     graph.add_branching_edge(
#         "MarketingStrategist",
#         condition=is_niche_market,
#         branches={
#             True: "NicheMarketSpecialist",
#             False: "End"
#         }
#     )
#     graph.add_edge("NicheMarketSpecialist", "End")

#     print("Executing the marketing workflow...")
#     graph.execute()

#     final_state = WorkflowState(**graph.get_graph_data())
#     print("\nFinal Workflow State:")
#     print(f"Products analyzed: {len(final_state.products)}")
#     print(f"Analyses created: {len(final_state.analyses)}")
#     print(f"Strategies developed: {len(final_state.strategies)}")

#     print("\nDetailed Results:")
#     for product, analysis, strategy in zip(final_state.products, final_state.analyses, final_state.strategies):
#         print(f"\nProduct: {product}")
#         print(f"Market Size: {analysis.market_size}")
#         print(f"Target Audience: {analysis.target_audience}")
#         print(f"Analysis summary: {analysis.analysis[:100]}...")
#         print(f"Strategy summary: {strategy.strategy[:100]}...")

#     print("\nAgent Memories:")
#     for agent_id in graph.agent_ids:
#         print(f"\nAgent {agent_id}:")
#         for message in graph.get_agentic_memory(agent_id):
#             print(f"- {message['role']}: {message['content'][:50]}...")

# if __name__ == "__main__":
#     test_marketing_workflow()

# %%
# import openai
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os
# # Set up OpenAI client
# openapi_key = "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"

# client = openai.OpenAI(api_key=openapi_key)

# class ProductAnalysis(BaseModel):
#     product_name: str
#     analysis: str
#     market_size: str
#     target_audience: str

# class MarketingStrategy(BaseModel):
#     product_name: str
#     strategy: str

# class WorkflowState(BaseModel):
#     products: List[str]
#     analyses: List[ProductAnalysis] = Field(default_factory=list)
#     strategies: List[MarketingStrategy] = Field(default_factory=list)

# # Define agent functions
# def market_analyst(graph_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As the Lead Market Analyst at a premier digital marketing firm, you specialize in dissecting online business landscapes. Your goal:
#     Conduct amazing analysis of the products and competitors, providing in-depth
#     insights to guide marketing strategies. Include market size and target audience in your analysis."""

#     # Use agentic memory to provide context
#     context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])
    
#     for product in state.products:
#         # Check if analysis for this product already exists in memory
#         existing_analysis = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and product in msg['content']), None)
        
#         if existing_analysis:
#             print(f"Using existing analysis for {product}")
#             analysis = existing_analysis['content']
#         else:
#             print(f"Generating new analysis for {product}")
#             response = client.chat.completions.create(
#                 model="gpt-3.5-turbo",
#                 messages=[
#                     {"role": "system", "content": system_prompt},
#                     {"role": "user", "content": f"Previous context:\n{context}\n\nAnalyze the product: {product}"}
#                 ]
#             )
#             analysis = response.choices[0].message.content

#         # Extract market size and target audience from the analysis
#         # For simplicity, we're using placeholder logic here. In a real scenario, you'd want to parse the analysis text.
#         market_size = "Large" if "large market" in analysis.lower() else "Small"
#         target_audience = "General consumers" if "general" in analysis.lower() else "Niche market"
        
#         state.analyses.append(ProductAnalysis(
#             product_name=product,
#             analysis=analysis,
#             market_size=market_size,
#             target_audience=target_audience
#         ))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Analyzed {len(state.products)} products",
#         result=len(state.analyses),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def marketing_strategist(graph_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """You are the Chief Marketing Strategist at a leading digital marketing agency, known for crafting bespoke strategies that drive success. Your goal:
#     Synthesize amazing insights from product analysis to formulate incredible
#     marketing strategies."""

#     # Use agentic memory to provide context
#     context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])

#     for analysis in state.analyses:
#         # Check if strategy for this product already exists in memory
#         existing_strategy = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and analysis.product_name in msg['content']), None)
        
#         if existing_strategy:
#             print(f"Using existing strategy for {analysis.product_name}")
#             strategy = existing_strategy['content']
#         else:
#             print(f"Generating new strategy for {analysis.product_name}")
#             response = client.chat.completions.create(
#                 model="gpt-3.5-turbo",
#                 messages=[
#                     {"role": "system", "content": system_prompt},
#                     {"role": "user", "content": f"Previous context:\n{context}\n\nCreate a marketing strategy based on this analysis: {analysis.analysis}"}
#                 ]
#             )
#             strategy = response.choices[0].message.content

#         state.strategies.append(MarketingStrategy(product_name=analysis.product_name, strategy=strategy))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Created strategies for {len(state.analyses)} products",
#         result=len(state.strategies),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def niche_market_specialist(graph_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As a Niche Market Specialist, your expertise lies in tailoring strategies for products with smaller, highly specific target audiences. Your goal:
#     Refine the existing marketing strategies to better suit niche markets and specialized consumer groups."""

#     # Use agentic memory to provide context
#     context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])

#     for analysis, strategy in zip(state.analyses, state.strategies):
#         if analysis.market_size == "Small" and "niche" in analysis.target_audience.lower():
#             # Check if refined strategy for this product already exists in memory
#             existing_refined_strategy = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and f"Refined strategy for {analysis.product_name}" in msg['content']), None)
            
#             if existing_refined_strategy:
#                 print(f"Using existing refined strategy for {analysis.product_name}")
#                 refined_strategy = existing_refined_strategy['content']
#             else:
#                 print(f"Generating new refined strategy for {analysis.product_name}")
#                 response = client.chat.completions.create(
#                     model="gpt-3.5-turbo",
#                     messages=[
#                         {"role": "system", "content": system_prompt},
#                         {"role": "user", "content": f"Previous context:\n{context}\n\nRefine this strategy for a niche market:\nProduct: {analysis.product_name}\nAnalysis: {analysis.analysis}\nCurrent Strategy: {strategy.strategy}"}
#                     ]
#                 )
#                 refined_strategy = response.choices[0].message.content

#             strategy.strategy = refined_strategy

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Refined strategies for niche markets",
#         result=len([s for s in state.strategies if "niche" in s.strategy.lower()]),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# # Conditional function for branching
# def is_niche_market(graph_data: Dict[str, Any]) -> bool:
#     state = WorkflowState(**graph_data)
#     return any(analysis.market_size == "Small" and "niche" in analysis.target_audience.lower() for analysis in state.analyses)

# # Test function
# def test_marketing_workflow():
#     initial_state = WorkflowState(products=["Smartphone", "Custom Mechanical Keyboard", "Smart Watch"])
    
#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")
    
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     graph.add_node("NicheMarketSpecialist", niche_market_specialist, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("MarketAnalyst", "MarketingStrategist")
    
#     # Add branching edge
#     graph.add_branching_edge(
#         "MarketingStrategist",
#         condition=is_niche_market,
#         branches={
#             True: "NicheMarketSpecialist",
#             False: "End"
#         }
#     )
#     graph.add_edge("NicheMarketSpecialist", "End")

#     print("Executing the marketing workflow...")
#     graph.execute()

#     final_state = WorkflowState(**graph.get_graph_data())
#     print("\nFinal Workflow State:")
#     print(f"Products analyzed: {len(final_state.products)}")
#     print(f"Analyses created: {len(final_state.analyses)}")
#     print(f"Strategies developed: {len(final_state.strategies)}")

#     print("\nDetailed Results:")
#     for product, analysis, strategy in zip(final_state.products, final_state.analyses, final_state.strategies):
#         print(f"\nProduct: {product}")
#         print(f"Market Size: {analysis.market_size}")
#         print(f"Target Audience: {analysis.target_audience}")
#         print(f"Analysis summary: {analysis.analysis[:100]}...")
#         print(f"Strategy summary: {strategy.strategy[:100]}...")

#     print("\nAgent Memories:")
#     for agent_id in graph.agent_ids:
#         print(f"\nAgent {agent_id}:")
#         for message in graph.get_agentic_memory(agent_id):
#             print(f"- {message['role']}: {message['content'][:50]}...")

#     # Run the workflow again to demonstrate memory usage
#     print("\nRunning the workflow again to demonstrate memory usage...")
#     graph.execute()

#     # Print updated agent memories
#     print("\nUpdated Agent Memories after second run:")
#     for agent_id in graph.agent_ids:
#         print(f"\nAgent {agent_id}:")
#         for message in graph.get_agentic_memory(agent_id):
#             print(f"- {message['role']}: {message['content'][:50]}...")

# if __name__ == "__main__":
#     test_marketing_workflow()

# %%
# import openai
# import json
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os

# # # Set up OpenAI client
# openapi_key = "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"

# client = openai.OpenAI(api_key=openapi_key)

# # Define MessageDict
# class MessageDict(BaseModel):
#     role: str
#     content: str
#     tool_call: bool = False
#     tool_args: Optional[Dict[str, Any]] = None
#     result: Any = None
#     create_agent_msg: bool = True
#     node_index: Optional[Tuple[str, str, int]] = None
#     execution_id: str = ""  # Default to empty string

# # Define WorkflowState
# class WorkflowState(BaseModel):
#     products: List[str] = Field(default_factory=list)
#     analyses: List[Dict[str, Any]] = Field(default_factory=list)
#     competitor_analyses: List[Dict[str, Any]] = Field(default_factory=list)
#     strategies: List[Dict[str, Any]] = Field(default_factory=list)

# def get_openai_response(prompt: str) -> str:
#     try:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[{"role": "user", "content": prompt}]
#         )
#         return response.choices[0].message.content.strip()
#     except Exception as e:
#         print(f"Error in OpenAI API call: {e}")
#         return "[Error: Could not generate content]"


# def process_input_data(input_data: Dict[str, Any]) -> WorkflowState:
#     combined_state = WorkflowState()
#     for state_data in input_data.values():
#         if isinstance(state_data, dict):
#             state = WorkflowState(**state_data)
#         elif isinstance(state_data, WorkflowState):
#             state = state_data
#         else:
#             raise ValueError(f"Unexpected input type: {type(state_data)}")
        
#         combined_state.products.extend(state.products)
#         combined_state.analyses.extend(state.analyses)
#         combined_state.competitor_analyses.extend(state.competitor_analyses)
#         combined_state.strategies.extend(state.strategies)
    
#     # Remove duplicates while preserving order
#     combined_state.products = list(dict.fromkeys(combined_state.products))
#     return combined_state

# def market_analyst(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     state = process_input_data(input_data)
    
#     analyses = []
#     for product in state.products:
#         prompt = f"Provide a brief market analysis for {product}. Include market size (Large or Small) and target audience (General or Niche)."
#         analysis = get_openai_response(prompt)
#         market_size = "Large" if "large" in analysis.lower() else "Small"
#         target_audience = "General" if "general" in analysis.lower() else "Niche"
#         analyses.append({"product": product, "analysis": analysis, "market_size": market_size, "target_audience": target_audience})

#     state.analyses = analyses

#     return {
#         "graph_data": state.dict(),
#         "metahistory": MessageDict(
#             role="assistant",
#             content=f"Analyzed {len(state.products)} products",
#             result=len(analyses),
#             create_agent_msg=True
#         ).dict()
#     }
    


# def competitor_analyst(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     state = process_input_data(input_data)
    
#     competitor_analyses = []
#     for product in state.products:
#         prompt = f"Provide a brief competitor analysis for {product}. Mention key competitors and their strengths."
#         analysis = get_openai_response(prompt)
#         competitor_analyses.append({"product": product, "analysis": analysis})

#     state.competitor_analyses = competitor_analyses

#     return {
#         "graph_data": state.dict(),
#         "metahistory": MessageDict(
#             role="assistant",
#             content=f"Analyzed competitors for {len(state.products)} products",
#             result=len(competitor_analyses),
#             create_agent_msg=True
#         ).dict()
#     }

# def marketing_strategist(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     state = process_input_data(input_data)
    
#     strategies = []
#     for product in state.products:
#         market_analysis = next((a['analysis'] for a in state.analyses if a['product'] == product), "No market analysis available")
#         competitor_analysis = next((a['analysis'] for a in state.competitor_analyses if a['product'] == product), "No competitor analysis available")
        
#         prompt = f"""Create a marketing strategy for {product} based on the following information:

# Market Analysis: {market_analysis}

# Competitor Analysis: {competitor_analysis}

# Provide a comprehensive strategy that leverages the market insights and addresses the competitive landscape."""

#         strategy = get_openai_response(prompt)
#         strategies.append({"product": product, "strategy": strategy})

#     state.strategies = strategies

#     return {
#         "graph_data": state.dict(),
#         "metahistory": MessageDict(
#             role="assistant",
#             content=f"Developed strategies for {len(strategies)} products",
#             result=len(strategies),
#             create_agent_msg=True
#         ).dict()
#     }

# def niche_market_specialist(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     state = process_input_data(input_data)
    
#     refined_strategies = []
#     for product in state.products:
#         analysis = next((a for a in state.analyses if a['product'] == product), None)
#         strategy = next((s for s in state.strategies if s['product'] == product), None)
        
#         if analysis and strategy and analysis["market_size"] == "Small" and analysis["target_audience"] == "Niche":
#             prompt = f"Refine the following marketing strategy for a niche market:\n\nProduct: {product}\nOriginal Strategy: {strategy['strategy']}\n\nProvide a more targeted approach for this niche market."
#             refined_strategy = get_openai_response(prompt)
#             refined_strategies.append({"product": product, "strategy": refined_strategy})
#         elif strategy:
#             refined_strategies.append(strategy)

#     state.strategies = refined_strategies

#     return {
#         "graph_data": state.dict(),
#         "metahistory": MessageDict(
#             role="assistant",
#             content=f"Refined strategies for niche markets",
#             result=len([s for s in refined_strategies if s != strategy]),
#             create_agent_msg=True
#         ).dict()
#     }

# # Update the conditional function for branching
# def is_niche_market(input_data: Dict[str, Any]) -> bool:
#     state = process_input_data(input_data)
#     return any(analysis["market_size"] == "Small" and analysis["target_audience"] == "Niche" for analysis in state.analyses)




# def test_marketing_workflow():
#     initial_state = WorkflowState(products=["Smartphone", "Custom Mechanical Keyboard", "Smart Watch", "Niche Gadget"])
    
#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")
    
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     graph.add_node("CompetitorAnalyst", competitor_analyst, is_agent=True)
#     graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     graph.add_node("NicheMarketSpecialist", niche_market_specialist, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("Start", "CompetitorAnalyst")
#     graph.add_edge("MarketAnalyst", "MarketingStrategist", is_required=True)
#     graph.add_edge("CompetitorAnalyst", "MarketingStrategist", is_required=True)
    
#     graph.add_branching_edge(
#         "MarketingStrategist",
#         condition=is_niche_market,
#         branches={
#             True: "NicheMarketSpecialist",
#             False: "End"
#         },
#     )
#     graph.add_edge("NicheMarketSpecialist", "End")

#     print("Graph structure and dependencies:")
#     for node_id, node in graph.nodes.items():
#         print(f"Node: {node_id}")
#         previous_nodes = graph.get_previous_nodes(node)
#         print(f"  Previous nodes: {[prev.name for prev in previous_nodes]}")
#         required_deps = graph.required_dependencies.get(node_id, set())
#         print(f"  Required dependencies: {required_deps}")

#     print("\nExecuting the marketing workflow...")
#     result = graph.execute()
#     execution_id = graph.current_execution_id

#     print(f"\nExecution ID: {execution_id}")
#     print("\nNode Graph State:")
#     node_graph_state = graph.get_node_graph_state(execution_id)
#     for node_name, state in node_graph_state.items():
#         print(f"Node: {node_name}")
#         if isinstance(state, dict):
#             print(json.dumps(state, indent=2))
#         else:
#             print(f"  State: {state}")

#     print("\nExecution order based on dependencies:")
#     execution_order = list(node_graph_state.keys())
#     for i, node_name in enumerate(execution_order):
#         print(f"{i+1}. {node_name}")

#     print("\nMetahistory:")
#     metahistory = graph.get_metahistory(execution_id=execution_id)
#     for entry_id in metahistory[1]:
#         entry = metahistory[0][entry_id]
#         print(f"- {entry.role}: {entry.content}")

#     print("\nAgentic Memory:")
#     for agent_id in graph.agent_ids:
#         print(f"Agent {agent_id}:")
#         for message in graph.get_agentic_memory(agent_id, execution_id):
#             print(f"- {message['role']}: {message['content']}")

#     # Visualize the graph
#     #graph.save_graph_visualiza tion("marketing_workflow_graph")

# test_marketing_workflow()

# %%
# import openai
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os
# import logging
# import uuid
# import time

# # # Set up OpenAI client
# openapi_key = "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"

# client = openai.OpenAI(api_key=openapi_key)


# # Define MessageDict
# class MessageDict(BaseModel):
#     role: str
#     content: str
#     tool_call: bool = False
#     tool_args: Optional[Dict[str, Any]] = None
#     result: Any = None
#     create_agent_msg: bool = True
#     node_index: Optional[Tuple[str, str, int]] = None
#     execution_id: str = ""

# # Define WorkflowState
# class WorkflowState(BaseModel):
#     products: List[str] = Field(default_factory=list)
#     analyses: List[Dict[str, Any]] = Field(default_factory=list)
#     competitor_analyses: List[Dict[str, Any]] = Field(default_factory=list)
#     strategies: List[Dict[str, Any]] = Field(default_factory=list)

# # Define custom exceptions
# class ExecutionError(Exception):
#     pass

# # Helper function to get OpenAI response
# def get_openai_response(prompt: str) -> str:
#     try:
#         response = openai.ChatCompletion.create(
#             model="gpt-3.5-turbo",
#             messages=[{"role": "user", "content": prompt}]
#         )
#         return response.choices[0].message.content.strip()
#     except Exception as e:
#         logging.error(f"Error in OpenAI API call: {e}")
#         return "[Error: Could not generate content]"
        
# def process_input_data(input_data: Union[Dict[str, Any], List[Any]]) -> WorkflowState:
#     combined_state = WorkflowState()
    
#     # If input_data is a dictionary, convert it to a list
#     if isinstance(input_data, dict):
#         input_data = list(input_data.values())
    
#     # Ensure input_data is a list
#     if not isinstance(input_data, list):
#         input_data = [input_data]
    
#     for state_data in input_data:
#         if isinstance(state_data, dict):
#             if "graph_data" in state_data:
#                 state_data = state_data["graph_data"]
#             state = WorkflowState(**state_data)
#         elif isinstance(state_data, WorkflowState):
#             state = state_data
#         elif isinstance(state_data, list):
#             # If state_data is a list, assume it's a list of analyses
#             state = WorkflowState(analyses=state_data)
#         else:
#             raise ValueError(f"Unexpected input type: {type(state_data)}")
        
#         combined_state.products.extend(state.products)
#         combined_state.analyses.extend(state.analyses)
#         combined_state.competitor_analyses.extend(state.competitor_analyses)
#         combined_state.strategies.extend(state.strategies)
    
#     # Remove duplicates while preserving order
#     combined_state.products = list(dict.fromkeys(combined_state.products))
#     combined_state.analyses = [dict(t) for t in {tuple(d.items()) for d in combined_state.analyses}]
#     combined_state.competitor_analyses = list(dict.fromkeys(combined_state.competitor_analyses))
#     combined_state.strategies = list(dict.fromkeys(combined_state.strategies))
    
#     return combined_state

# # Node functions
# def market_analyst(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     try:
#         state = process_input_data(input_data)
        
#         analyses = []
#         for product in state.products:
#             prompt = f"Provide a brief market analysis for {product}. Include market size (Large or Small) and target audience (General or Niche)."
#             analysis = get_openai_response(prompt)
#             market_size = "Large" if "large" in analysis.lower() else "Small"
#             target_audience = "General" if "general" in analysis.lower() else "Niche"
#             analyses.append({"product": product, "analysis": analysis, "market_size": market_size, "target_audience": target_audience})

#         state.analyses = analyses

#         return {
#             "graph_data": state.dict(),
#             "metahistory": MessageDict(
#                 role="assistant",
#                 content=f"Analyzed {len(state.products)} products",
#                 result=len(analyses),
#                 create_agent_msg=True
#             ).dict()
#         }
#     except Exception as e:
#         logging.error(f"Error in market_analyst: {str(e)}")
#         raise

# def competitor_analyst(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     try:
#         state = process_input_data(input_data)
        
#         competitor_analyses = []
#         for product in state.products:
#             prompt = f"Provide a brief competitor analysis for {product}. Mention key competitors and their strengths."
#             analysis = get_openai_response(prompt)
#             competitor_analyses.append({"product": product, "analysis": analysis})

#         state.competitor_analyses = competitor_analyses

#         return {
#             "graph_data": state.dict(),
#             "metahistory": MessageDict(
#                 role="assistant",
#                 content=f"Analyzed competitors for {len(state.products)} products",
#                 result=len(competitor_analyses),
#                 create_agent_msg=True
#             ).dict()
#         }
#     except Exception as e:
#         logging.error(f"Error in competitor_analyst: {str(e)}")
#         raise

# def marketing_strategist(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     try:
#         state = process_input_data(input_data)
        
#         strategies = []
#         for product in state.products:
#             market_analysis = next((a['analysis'] for a in state.analyses if a['product'] == product), "No market analysis available")
#             competitor_analysis = next((a['analysis'] for a in state.competitor_analyses if a['product'] == product), "No competitor analysis available")
            
#             prompt = f"""Create a marketing strategy for {product} based on the following information:

#     Market Analysis: {market_analysis}

#     Competitor Analysis: {competitor_analysis}

#     Provide a comprehensive strategy that leverages the market insights and addresses the competitive landscape."""

#             strategy = get_openai_response(prompt)
#             strategies.append({"product": product, "strategy": strategy})

#         state.strategies = strategies

#         return {
#             "graph_data": state.dict(),
#             "metahistory": MessageDict(
#                 role="assistant",
#                 content=f"Developed strategies for {len(strategies)} products",
#                 result=len(strategies),
#                 create_agent_msg=True
#             ).dict()
#         }
#     except Exception as e:
#         logging.error(f"Error in marketing_strategist: {str(e)}")
#         raise

# def niche_market_specialist(input_data: Dict[str, Any], agentic_memory: Optional[List[Dict[str, Any]]] = None) -> Dict[str, Any]:
#     try:
#         state = process_input_data(input_data)
        
#         refined_strategies = []
#         for product in state.products:
#             analysis = next((a for a in state.analyses if a['product'] == product), None)
#             strategy = next((s for s in state.strategies if s['product'] == product), None)
            
#             if analysis and strategy and analysis["market_size"] == "Small" and analysis["target_audience"] == "Niche":
#                 prompt = f"Refine the following marketing strategy for a niche market:\n\nProduct: {product}\nOriginal Strategy: {strategy['strategy']}\n\nProvide a more targeted approach for this niche market."
#                 refined_strategy = get_openai_response(prompt)
#                 refined_strategies.append({"product": product, "strategy": refined_strategy})
#             elif strategy:
#                 refined_strategies.append(strategy)

#         state.strategies = refined_strategies

#         return {
#             "graph_data": state.dict(),
#             "metahistory": MessageDict(
#                 role="assistant",
#                 content=f"Refined strategies for niche markets",
#                 result=len([s for s in refined_strategies if s != strategy]),
#                 create_agent_msg=True
#             ).dict()
#         }
#     except Exception as e:
#         logging.error(f"Error in niche_market_specialist: {str(e)}")
#         raise

# # Conditional function for branching
# def is_niche_market(input_data: Dict[str, Any]) -> bool:
#     state = process_input_data(input_data)
#     return any(analysis["market_size"] == "Small" and analysis["target_audience"] == "Niche" for analysis in state.analyses)


# # Test function
# def test_marketing_workflow():
#     # Set up logging
#     logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

#     # Initialize workflow
#     initial_state = WorkflowState(products=["Smartphone", "Custom Mechanical Keyboard", "Smart Watch", "Niche Gadget"])
#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")

#     # Add nodes
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     graph.add_node("CompetitorAnalyst", competitor_analyst, is_agent=True)
#     graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     graph.add_node("NicheMarketSpecialist", niche_market_specialist, is_agent=True)
#     graph.add_node(EndNode())

#     # Add edges
#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("Start", "CompetitorAnalyst")
#     graph.add_edge("MarketAnalyst", "MarketingStrategist", is_required=True)
#     graph.add_edge("CompetitorAnalyst", "MarketingStrategist", is_required=True)
    
#     graph.add_branching_edge(
#         "MarketingStrategist",
#         condition=is_niche_market,
#         branches={
#             True: "NicheMarketSpecialist",
#             False: "End"
#         },
#     )
#     graph.add_edge("NicheMarketSpecialist", "End")

#     print("Graph structure and dependencies:")
#     for node_id, node in graph.nodes.items():
#         print(f"Node: {node_id}")
#         previous_nodes = graph.get_previous_nodes(node)
#         print(f"  Previous nodes: {[prev.name for prev in previous_nodes]}")
#         required_deps = graph.required_dependencies.get(node_id, set())
#         print(f"  Required dependencies: {required_deps}")

#     print("\nExecuting the marketing workflow...")
#     result = graph.execute()
#     execution_id = graph.current_execution_id

#     print(f"\nExecution ID: {execution_id}")
#     print("\nNode Graph State:")
#     node_graph_state = graph.get_node_graph_state(execution_id)
#     for node_name, state in node_graph_state.items():
#         print(f"Node: {node_name}")
#         if isinstance(state, dict):
#             print(json.dumps(state, indent=2))
#         else:
#             print(f"  State: {state}")

# if __name__ == "__main__":
#     test_marketing_workflow()

# %%
# import openai
# import json
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os

# # # Set up OpenAI client
# openapi_key = "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"

# client = openai.OpenAI(api_key=openapi_key)


# class ProductAnalysis(BaseModel):
#     product_name: str
#     analysis: str
#     market_size: str
#     target_audience: str

# class MarketingStrategy(BaseModel):
#     product_name: str
#     strategy: str

# class WorkflowState(BaseModel):
#     products: List[str]
#     analyses: List[ProductAnalysis] = Field(default_factory=list)
#     strategies: List[MarketingStrategy] = Field(default_factory=list)

# # Updated agent functions
# def market_analyst(input_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
#     # Get the state from the input data
#     state = WorkflowState(**(input_data.get('Start', {}) or input_data.get('MarketAnalyst', {})))


#     print("input_data i get ", input_data)
    
#     print("State i get ", state)

#     system_prompt = """As the Lead Market Analyst at a premier digital marketing firm, you specialize in dissecting online business landscapes. Your goal:
#     Conduct amazing analysis of the products and competitors, providing in-depth
#     insights to guide marketing strategies. Include market size and target audience in your analysis."""

#     # Use agentic memory to provide context
#     context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])

#     for product in state.products:
#         # Check if analysis for this product already exists in memory
#         existing_analysis = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and product in msg['content']), None)

#         if existing_analysis:
#             print(f"Using existing analysis for {product}")
#             analysis = existing_analysis['content']
#         else:
#             print(f"Generating new analysis for {product}")
#             response = client.chat.completions.create(
#                 model="gpt-3.5-turbo",
#                 messages=[
#                     {"role": "system", "content": system_prompt},
#                     {"role": "user", "content": f"Previous context:\n{context}\n\nAnalyze the product: {product}"}
#                 ]
#             )
#             analysis = response.choices[0].message.content

#         # Extract market size and target audience from the analysis
#         # For simplicity, we're using placeholder logic here. In a real scenario, you'd want to parse the analysis text.
#         market_size = "Large" if "large market" in analysis.lower() else "Small"
#         target_audience = "General consumers" if "general" in analysis.lower() else "Niche market"

#         state.analyses.append(ProductAnalysis(
#             product_name=product,
#             analysis=analysis,
#             market_size=market_size,
#             target_audience=target_audience
#         ))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Analyzed {len(state.products)} products",
#         result=len(state.analyses),
#         create_agent_msg=True,
#         tool_call=False
#     )

#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def marketing_strategist(input_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
#     # Get the state from the input data
#     state = WorkflowState(**(input_data.get('MarketAnalyst', {}) or input_data.get('MarketingStrategist', {})))

#     system_prompt = """You are the Chief Marketing Strategist at a leading digital marketing agency, known for crafting bespoke strategies that drive success. Your goal:
#     Synthesize amazing insights from product analysis to formulate incredible
#     marketing strategies."""

#     # Use agentic memory to provide context
#     context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])

#     for analysis in state.analyses:
#         # Check if strategy for this product already exists in memory
#         existing_strategy = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and analysis.product_name in msg['content']), None)

#         if existing_strategy:
#             print(f"Using existing strategy for {analysis.product_name}")
#             strategy = existing_strategy['content']
#         else:
#             print(f"Generating new strategy for {analysis.product_name}")
#             response = client.chat.completions.create(
#                 model="gpt-3.5-turbo",
#                 messages=[
#                     {"role": "system", "content": system_prompt},
#                     {"role": "user", "content": f"Previous context:\n{context}\n\nCreate a marketing strategy based on this analysis: {analysis.analysis}"}
#                 ]
#             )
#             strategy = response.choices[0].message.content

#         state.strategies.append(MarketingStrategy(product_name=analysis.product_name, strategy=strategy))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Created strategies for {len(state.analyses)} products",
#         result=len(state.strategies),
#         create_agent_msg=True,
#         tool_call=False
#     )

#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def niche_market_specialist(input_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
#     # Get the state from the input data
#     state = WorkflowState(**(input_data.get('MarketingStrategist', {}) or input_data.get('NicheMarketSpecialist', {})))

#     system_prompt = """As a Niche Market Specialist, your expertise lies in tailoring strategies for products with smaller, highly specific target audiences. Your goal:
#     Refine the existing marketing strategies to better suit niche markets and specialized consumer groups."""

#     # Use agentic memory to provide context
#     context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])

#     for analysis, strategy in zip(state.analyses, state.strategies):
#         if analysis.market_size == "Small" and "niche" in analysis.target_audience.lower():
#             # Check if refined strategy for this product already exists in memory
#             existing_refined_strategy = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and f"Refined strategy for {analysis.product_name}" in msg['content']), None)

#             if existing_refined_strategy:
#                 print(f"Using existing refined strategy for {analysis.product_name}")
#                 refined_strategy = existing_refined_strategy['content']
#             else:
#                 print(f"Generating new refined strategy for {analysis.product_name}")
#                 response = client.chat.completions.create(
#                     model="gpt-3.5-turbo",
#                     messages=[
#                         {"role": "system", "content": system_prompt},
#                         {"role": "user", "content": f"Previous context:\n{context}\n\nRefine this strategy for a niche market:\nProduct: {analysis.product_name}\nAnalysis: {analysis.analysis}\nCurrent Strategy: {strategy.strategy}"}
#                     ]
#                 )
#                 refined_strategy = response.choices[0].message.content

#             strategy.strategy = refined_strategy

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Refined strategies for niche markets",
#         result=len([s for s in state.strategies if "niche" in s.strategy.lower()]),
#         create_agent_msg=True,
#         tool_call=False
#     )

#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# # Conditional function for branching
# def is_niche_market(graph_data: Dict[str, Any]) -> bool:
#     state = WorkflowState(**graph_data)
#     return any(analysis.market_size == "Small" and "niche" in analysis.target_audience.lower() for analysis in state.analyses)

# # New function to demonstrate error handling
# def error_prone_function(input_data: Dict[str, Any]) -> Dict[str, Any]:
#     if random.random() < 0.5:  # 50% chance of error
#         raise ExecutionError("Simulated error in error_prone_function")
#     return {"graph_data": input_data, "metahistory": None}

# # Test function
# def test_marketing_workflow():
#     initial_state = WorkflowState(products=["Smartphone", "Custom Mechanical Keyboard", "Smart Watch"])

#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")

#     # Add nodes
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     # graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     # graph.add_node("NicheMarketSpecialist", niche_market_specialist, is_agent=True)
#     # graph.add_node("ErrorProneNode", error_prone_function)
#     graph.add_node(EndNode())

#     # Add edges
#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("MarketAnalyst", "End")
#     # graph.add_edge("MarketAnalyst", "MarketingStrategist")
#     # graph.add_edge("MarketingStrategist", "ErrorProneNode")

#     # # Add branching edge
#     # graph.add_branching_edge(
#     #     "ErrorProneNode",
#     #     condition=is_niche_market, 
#     #     branches={
#     #         True: "NicheMarketSpecialist",
#     #         False: "End"
#     #     }
#     # )
#     # graph.add_edge("NicheMarketSpecialist", "End")

#     print("Graph structure and dependencies:")
#     for node_id, node in graph.nodes.items():
#         print(f"Node: {node_id}")
#         previous_nodes = graph.get_previous_nodes(node)
#         print(f"  Previous nodes: {[prev.name for prev in previous_nodes]}")
#         required_deps = graph.required_dependencies.get(node_id, set())
#         print(f"  Required dependencies: {required_deps}")


#     print("Executing the marketing workflow...")
#     graph.execute()  # Test parallel execution

#     # Test graph visualization
#     # graph.save_graph_visualization("marketing_workflow_graph.png")

#     # Test getting execution data
#     execution_id = graph.get_execution_ids()[-1]
#     execution_data = graph.get_execution_data(execution_id)
#     print("\nExecution Data:")
#     print(f"Metahistory entries: {len(execution_data['metahistory'][1])}")
#     print(f"Agentic memory entries: {sum(len(mem) for mem in execution_data['agentic_memory'].values())}")
#     print(f"Node graph state entries: {len(execution_data['node_graph_state'])}")

#     # Test stopping and resuming execution
#     # print("\nTesting stop and resume functionality...")
#     # graph.stop_at_current_node()
#     # current_node = graph.get_current_node()
#     # print(f"Stopped at node: {current_node.name if current_node else 'None'}")
#     # graph.resume_execution()
#     # graph.execute()  # Continue execution

#     # Print final results
#     # final_state = WorkflowState(**graph.get_graph_data())
#     # print("\nFinal Workflow State:")
#     # print(f"Products analyzed: {len(final_state.products)}")
#     # print(f"Analyses created: {len(final_state.analyses)}")
#     # print(f"Strategies developed: {len(final_state.strategies)}")

#     # # Print agent memories
#     # print("\nAgent Memories:")
#     # for agent_id in graph.agent_ids:
#     #     print(f"\nAgent {agent_id}:")
#     #     for message in graph.get_agentic_memory(agent_id):
#     #         print(f"- {message['role']}: {message['content'][:50]}...")

#     # # Test multiple executions
#     # print("\nRunning the workflow again to demonstrate memory usage...")
#     # graph.execute()

#     # # Print updated agent memories
#     # print("\nUpdated Agent Memories after second run:")
#     # for agent_id in graph.agent_ids:
#     #     print(f"\nAgent {agent_id}:")
#     #     for message in graph.get_agentic_memory(agent_id):
#     #         print(f"- {message['role']}: {message['content'][:50]}...")

# test_marketing_workflow()

# %%
import openai
import json
from typing import Any, Dict, List, Optional, Tuple
from pydantic import BaseModel, Field
import os

import os
import sys
sys.path.append('/root/nightsky/NightSky')

from AgentGraph import AgenticGraph , MessageDict , StartNode , EndNode, DataSchema
from typing import Any, Callable, Dict, List, Optional, Union, TypedDict, Tuple, Type, TypeVar
from pydantic import BaseModel, Field
import json

class CustomDataSchema(BaseModel):
    common_key: str
    graph1_key: Optional[str] = None
    graph2_key: Optional[str] = None

# def test_inter_graph_communication():


# Define nodes for graph1
def node1_func(input_data):
    result = f"Processed in Graph 1: {input_data}"
    return {
        "graph_data": {"result": result, "common_key": "updated_by_graph1", "graph1_key": "new_graph1_value"},
        "metahistory": {
            "role": "system",
            "content": "Node1 processing complete",
            "tool_call": False,
            "result": result,
            "create_agent_msg": False
        }
    }

def node2_func(input_data):
    result = f"Final processing in Graph 1: {input_data}"
    return {
        "graph_data": {"result": result, "common_key": "final_update_by_graph1"},
        "metahistory": {
            "role": "system",
            "content": "Node2 processing complete",
            "tool_call": False,
            "result": result,
            "create_agent_msg": False
        }
    }

# Define nodes for graph2
def node3_func(input_data):
    print(f"Node3 received input_data: {input_data}")
    shared_data = input_data.get("common_key", "No shared data")
    result = f"Processed in Graph 2: {shared_data}"
    return {
        "graph_data": {"result": result, "common_key": "updated_by_graph2", "graph2_key": "new_graph2_value"},
        "metahistory": {
            "role": "system",
            "content": "Node3 processing complete",
            "tool_call": False,
            "result": result,
            "create_agent_msg": False
        }
    }

def node4_func(input_data):
    result = f"Processed in Graph 2 Node 4: {input_data}"
    return {
        "graph_data": {"result": result, "common_key": "updated_by_graph2_node4"},
        "metahistory": {
            "role": "system",
            "content": "Node4 processing complete",
            "tool_call": False,
            "result": result,
            "create_agent_msg": False
        }
    }

def node5_func(input_data):
    result = f"Processed in Graph 2 Node 5: {input_data}"
    return {
        "graph_data": {"result": result, "common_key": "updated_by_graph2_node5"},
        "metahistory": {
            "role": "system",
            "content": "Node5 processing complete",
            "tool_call": False,
            "result": result,
            "create_agent_msg": False
        }
    }

# Create two graphs with initial data and custom schema
graph1 = AgenticGraph(graph_id="graph1", chat_id="chat1", data_schema=CustomDataSchema)
graph2 = AgenticGraph(graph_id="graph2", chat_id="chat1", data_schema=CustomDataSchema)

# Connect the graphs
graph1.connect_graph(graph2)
graph2.connect_graph(graph1)

print("Graph 1 shared keys:", graph1.shared_keys)
print("Graph 2 shared keys:", graph2.shared_keys)

# Add nodes to graphs
graph1.add_node(StartNode())
graph1.add_node("Node1", node1_func)
graph1.add_node("Node2", node2_func)
graph1.add_node(EndNode())

graph2.add_node("Node3", node3_func)
graph2.add_node("Node4", node4_func)
graph2.add_node("Node5", node5_func)

# Add edges
graph1.add_edge("Start", "Node1")
graph1.add_edge("Node1", ("graph2", "Node3"))  # Edge from Graph1 to Graph2
graph2.add_edge("Node3", "Node4")
graph2.add_edge("Node4", "Node5")
graph2.add_edge("Node5", ("graph1", "Node2"))  # Edge from Graph2 back to Graph1
graph1.add_edge("Node2", "End")


# Execute the workflow with initial data
initial_data = {"common_key": "initial_value", "graph1_key": "graph1_value", "graph2_key": "graph2_value"}
graph1.execute(initial_data)

# Print results
print("Graph 1 data:", graph1.get_graph_data())
print("Graph 2 data:", graph2.get_graph_data())
print("Graph 1 shareable data with Graph 2:", graph1.get_shareable_data("graph2", "Node1"))
print("Graph 2 shareable data with Graph 1:", graph2.get_shareable_data("graph1", "Node5"))
print("Graph 1 shared keys:", graph1.shared_keys)
print("Graph 2 shared keys:", graph2.shared_keys)
print("Graph 1 metahistory:", graph1.get_metahistory())
print("Graph 2 metahistory:", graph2.get_metahistory())

# # Add this line at the end of the file
# if __name__ == "__main__":
#     test_inter_graph_communication()
# Out:
# 2024-08-30 14:52:03,594 - INFO - Starting graph execution from node 'Start'. Execution ID: 886376f4-7a5e-4302-a90e-911766be3b51
# 2024-08-30 14:52:03,595 - INFO - Processing node 'Start' in graph 'graph1'
# 2024-08-30 14:52:03,596 - INFO - Executing node 'Start' in graph 'graph1'
# 2024-08-30 14:52:03,596 - INFO - Starting execution with initial data: {'common_key': 'initial_value', 'graph1_key': 'graph1_value', 'graph2_key': 'graph2_value'}
# 2024-08-30 14:52:03,597 - INFO - Node 'Start' execution completed successfully
# 2024-08-30 14:52:03,598 - INFO - Updated node graph state for 'Start'
# 2024-08-30 14:52:03,598 - INFO - Moving to next node: 'Node1' in graph 'graph1'
# 2024-08-30 14:52:03,599 - INFO - Processing node 'Node1' in graph 'graph1'
# 2024-08-30 14:52:03,600 - INFO - Previous nodes for 'Node1': ['Start']
# 2024-08-30 14:52:03,601 - INFO - Executing node 'Node1' in graph 'graph1'
# 2024-08-30 14:52:03,602 - INFO - Node 'Node1' execution completed successfully
# 2024-08-30 14:52:03,603 - INFO - Updated node graph state for 'Node1'
# 2024-08-30 14:52:03,604 - INFO - Moving to next node: 'Node3' in graph 'graph2'
# 2024-08-30 14:52:03,605 - INFO - Processing node 'Node3' in graph 'graph2'
# 2024-08-30 14:52:03,606 - INFO - Previous nodes for 'Node3': ['graph1:Node1']
# 2024-08-30 14:52:03,607 - INFO - Previous node from connected graph: graph_id=graph1, node=Node1
# 2024-08-30 14:52:03,607 - INFO - Executing node 'Node3' in graph 'graph2'
# 2024-08-30 14:52:03,608 - INFO - Node 'Node3' execution completed successfully
# 2024-08-30 14:52:03,610 - INFO - Updated node graph state for 'Node3'
# 2024-08-30 14:52:03,611 - INFO - Moving to next node: 'Node4' in graph 'graph2'
# 2024-08-30 14:52:03,611 - INFO - Processing node 'Node4' in graph 'graph2'
# 2024-08-30 14:52:03,613 - INFO - Previous nodes for 'Node4': ['Node3']
# 2024-08-30 14:52:03,614 - INFO - Executing node 'Node4' in graph 'graph2'
# 2024-08-30 14:52:03,615 - INFO - Node 'Node4' execution completed successfully
# 2024-08-30 14:52:03,616 - INFO - Updated node graph state for 'Node4'
# 2024-08-30 14:52:03,617 - INFO - Moving to next node: 'Node5' in graph 'graph2'
# 2024-08-30 14:52:03,618 - INFO - Processing node 'Node5' in graph 'graph2'
# 2024-08-30 14:52:03,619 - INFO - Previous nodes for 'Node5': ['Node4']
# 2024-08-30 14:52:03,620 - INFO - Executing node 'Node5' in graph 'graph2'
# 2024-08-30 14:52:03,620 - INFO - Node 'Node5' execution completed successfully
# 2024-08-30 14:52:03,622 - INFO - Updated node graph state for 'Node5'
# 2024-08-30 14:52:03,623 - INFO - Moving to next node: 'Node2' in graph 'graph1'
# 2024-08-30 14:52:03,624 - INFO - Processing node 'Node2' in graph 'graph1'
# 2024-08-30 14:52:03,624 - INFO - Previous nodes for 'Node2': ['graph2:Node5']
# 2024-08-30 14:52:03,625 - INFO - Previous node from connected graph: graph_id=graph2, node=Node5
# 2024-08-30 14:52:03,626 - INFO - Executing node 'Node2' in graph 'graph1'
# 2024-08-30 14:52:03,627 - INFO - Node 'Node2' execution completed successfully
# 2024-08-30 14:52:03,628 - INFO - Updated node graph state for 'Node2'
# 2024-08-30 14:52:03,635 - INFO - Moving to next node: 'End' in graph 'graph1'
# 2024-08-30 14:52:03,636 - INFO - Processing node 'End' in graph 'graph1'
# 2024-08-30 14:52:03,637 - INFO - Previous nodes for 'End': ['Node2']
# 2024-08-30 14:52:03,637 - INFO - Executing node 'End' in graph 'graph1'
# 2024-08-30 14:52:03,638 - INFO - Execution ended with final data: {'Node2': {'result': "Final processing in Graph 1: {'Node5': {'common_key': 'updated_by_graph2_node5'}}", 'common_key': 'final_update_by_graph1'}}
# 2024-08-30 14:52:03,639 - INFO - Node 'End' execution completed successfully
# 2024-08-30 14:52:03,639 - INFO - Updated node graph state for 'End'
# 2024-08-30 14:52:03,640 - INFO - Reached EndNode: 'End'
# 2024-08-30 14:52:03,640 - INFO - Graph execution completed. Chat ID: chat1, Execution ID: 886376f4-7a5e-4302-a90e-911766be3b51
# Graph 1 shared keys: {'graph2': {'graph2_key', 'common_key', 'graph1_key'}}
# Graph 2 shared keys: {'graph1': {'graph2_key', 'common_key', 'graph1_key'}}
# Node3 received input_data: {'Node1': {'common_key': 'updated_by_graph1', 'graph1_key': 'new_graph1_value'}}
# Graph 1 data: {'Start': {'common_key': 'initial_value', 'graph1_key': 'graph1_value', 'graph2_key': 'graph2_value'}, 'Node1': {'result': "Processed in Graph 1: {'Start': {'common_key': 'initial_value', 'graph1_key': 'graph1_value', 'graph2_key': 'graph2_value'}}", 'common_key': 'updated_by_graph1', 'graph1_key': 'new_graph1_value'}, 'Node2': {'result': "Final processing in Graph 1: {'Node5': {'common_key': 'updated_by_graph2_node5'}}", 'common_key': 'final_update_by_graph1'}, 'End': {'Node2': {'result': "Final processing in Graph 1: {'Node5': {'common_key': 'updated_by_graph2_node5'}}", 'common_key': 'final_update_by_graph1'}}}
# Graph 2 data: {'Node3': {'result': 'Processed in Graph 2: No shared data', 'common_key': 'updated_by_graph2', 'graph2_key': 'new_graph2_value'}, 'Node4': {'result': "Processed in Graph 2 Node 4: {'Node3': {'result': 'Processed in Graph 2: No shared data', 'common_key': 'updated_by_graph2', 'graph2_key': 'new_graph2_value'}}", 'common_key': 'updated_by_graph2_node4'}, 'Node5': {'result': 'Processed in Graph 2 Node 5: {\'Node4\': {\'result\': "Processed in Graph 2 Node 4: {\'Node3\': {\'result\': \'Processed in Graph 2: No shared data\', \'common_key\': \'updated_by_graph2\', \'graph2_key\': \'new_graph2_value\'}}", \'common_key\': \'updated_by_graph2_node4\'}}', 'common_key': 'updated_by_graph2_node5'}}
# Graph 1 shareable data with Graph 2: {'common_key': 'updated_by_graph1', 'graph1_key': 'new_graph1_value'}
# Graph 2 shareable data with Graph 1: {'common_key': 'updated_by_graph2_node5'}
# Graph 1 shared keys: {'graph2': {'graph2_key', 'common_key', 'graph1_key'}}
# Graph 2 shared keys: {'graph1': {'graph2_key', 'common_key', 'graph1_key'}}
# Graph 1 metahistory: ({'28202852-ff2c-43cf-9945-f307e1027260': MessageDict(role='system', content='Node1 processing complete', tool_call=False, tool_args=None, result="Processed in Graph 1: {'Start': {'common_key': 'initial_value', 'graph1_key': 'graph1_value', 'graph2_key': 'graph2_value'}}", create_agent_msg=False, node_index=None, execution_id='886376f4-7a5e-4302-a90e-911766be3b51'), 'c6eabc9e-9dfc-4e39-85c8-f67876d6fd46': MessageDict(role='system', content='Node2 processing complete', tool_call=False, tool_args=None, result="Final processing in Graph 1: {'Node5': {'common_key': 'updated_by_graph2_node5'}}", create_agent_msg=False, node_index=None, execution_id='886376f4-7a5e-4302-a90e-911766be3b51')}, ['28202852-ff2c-43cf-9945-f307e1027260', 'c6eabc9e-9dfc-4e39-85c8-f67876d6fd46'])
# Graph 2 metahistory: ({'4a0a77d6-4cfa-4e7e-95ad-e674863c3ec0': MessageDict(role='system', content='Node3 processing complete', tool_call=False, tool_args=None, result='Processed in Graph 2: No shared data', create_agent_msg=False, node_index=None, execution_id=None), '4fd9da24-a285-4cc5-b787-a651686cbb8c': MessageDict(role='system', content='Node4 processing complete', tool_call=False, tool_args=None, result="Processed in Graph 2 Node 4: {'Node3': {'result': 'Processed in Graph 2: No shared data', 'common_key': 'updated_by_graph2', 'graph2_key': 'new_graph2_value'}}", create_agent_msg=False, node_index=None, execution_id=None), 'd0e05934-6e48-413a-82f0-09db225df8b0': MessageDict(role='system', content='Node5 processing complete', tool_call=False, tool_args=None, result='Processed in Graph 2 Node 5: {\'Node4\': {\'result\': "Processed in Graph 2 Node 4: {\'Node3\': {\'result\': \'Processed in Graph 2: No shared data\', \'common_key\': \'updated_by_graph2\', \'graph2_key\': \'new_graph2_value\'}}", \'common_key\': \'updated_by_graph2_node4\'}}', create_agent_msg=False, node_index=None, execution_id=None)}, ['4a0a77d6-4cfa-4e7e-95ad-e674863c3ec0', '4fd9da24-a285-4cc5-b787-a651686cbb8c', 'd0e05934-6e48-413a-82f0-09db225df8b0'])

# %%
print("Graph 1 data:", graph1.get_graph_data())
print("Graph 2 data:", graph2.get_graph_data())
# Out:
# Graph 1 data: {'Start': {'common_key': 'initial_value', 'graph1_key': 'graph1_value', 'graph2_key': 'graph2_value'}, 'Node1': {'result': "Processed in Graph 1: {'Start': {'common_key': 'initial_value', 'graph1_key': 'graph1_value', 'graph2_key': 'graph2_value'}}", 'common_key': 'updated_by_graph1', 'graph1_key': 'new_graph1_value'}, 'Node2': {'result': "Final processing in Graph 1: {'Node5': {'common_key': 'updated_by_graph2_node5'}}", 'common_key': 'final_update_by_graph1'}, 'End': {'Node2': {'result': "Final processing in Graph 1: {'Node5': {'common_key': 'updated_by_graph2_node5'}}", 'common_key': 'final_update_by_graph1'}}}
# Graph 2 data: {'Node3': {'result': 'Processed in Graph 2: No shared data', 'common_key': 'updated_by_graph2', 'graph2_key': 'new_graph2_value'}, 'Node4': {'result': "Processed in Graph 2 Node 4: {'Node3': {'result': 'Processed in Graph 2: No shared data', 'common_key': 'updated_by_graph2', 'graph2_key': 'new_graph2_value'}}", 'common_key': 'updated_by_graph2_node4'}, 'Node5': {'result': 'Processed in Graph 2 Node 5: {\'Node4\': {\'result\': "Processed in Graph 2 Node 4: {\'Node3\': {\'result\': \'Processed in Graph 2: No shared data\', \'common_key\': \'updated_by_graph2\', \'graph2_key\': \'new_graph2_value\'}}", \'common_key\': \'updated_by_graph2_node4\'}}', 'common_key': 'updated_by_graph2_node5'}}
