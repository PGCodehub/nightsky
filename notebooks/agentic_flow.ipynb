# %%
import os
import sys
sys.path.append('/root/nightsky/NightSky')

# %%
from AgentGraph import AgenticGraph , MessageDict , StartNode , EndNode
from typing import Any, Callable, Dict, List, Optional, Union, TypedDict, Tuple, Type, TypeVar
from pydantic import BaseModel, Field

# %%
# def main():
#     class Logs(BaseModel):
#         id: str
#         question: str
#         docs: Optional[List[Any]] = None
#         answer: str
#         grade: Optional[int] = None
#         grader: Optional[str] = None
#         feedback: Optional[str] = None

#     class FailureAnalysisState(BaseModel):
#         docs: List[Logs]
#         failures: List[Logs] = Field(default_factory=list)
#         fa_summary: str = ""


#     def process_logs(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#         print("Processing logs...")
#         state = FailureAnalysisState(**graph_data)
#         state.failures = [log for log in state.docs if log.grade is not None and log.grade < 5]
#         metahistory = MessageDict(
#             role="system",
#             content="Processed logs",
#             result=len(state.failures),
#             create_agent_msg=True
#         )
#         return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

#     def analyze_failures(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#         print("Analyzing failures...")
#         state = FailureAnalysisState(**graph_data)
#         state.fa_summary = f"Found {len(state.failures)} failures out of {len(state.docs)} total logs."
#         metahistory = MessageDict(
#             role="assistant",
#             content=f"Analyzed failures: {state.fa_summary}",
#             result=state.fa_summary,
#             create_agent_msg=True
#         )
#         return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

#     # Initialize the graph with the FailureAnalysisState
#     initial_state = FailureAnalysisState(
#         docs=[
#             Logs(id='1', question='Q1', answer='A1', grade=4),
#             Logs(id='2', question='Q2', answer='A2', grade=7),
#             Logs(id='3', question='Q3', answer='A3', grade=3),
#         ]
#     )
#     graph = AgenticGraph(initial_state.dict(), chat_id="example_chat")
    
#     graph.add_node(StartNode())
#     graph.add_node("ProcessLogs", process_logs, is_agent=True)
#     graph.add_node("AnalyzeFailures", analyze_failures, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "ProcessLogs")
#     graph.add_edge("ProcessLogs", "AnalyzeFailures")
#     graph.add_edge("AnalyzeFailures", "End")

#     # Execute the graph
#     print("Executing the graph...")
#     graph.execute()

#     print("Final Graph Data:", graph.get_graph_data())
#     metahistory_dict, metahistory_order = graph.get_metahistory()
#     print("Metahistory entries:", metahistory_dict)
#     print("Metahistory order:", metahistory_order)

#     # Print agentic memory for each agent
#     for agent_id in graph.agent_ids:
#         print(f"Agentic Memory for agent {agent_id}:")
#         print(graph.get_agentic_memory(agent_id))

# if __name__ == "__main__":
#     main()

# %%
# import openai
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os

# openapi_key = "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"

# # Set up OpenAI client
# client = openai.OpenAI(api_key=openapi_key)


# class MessageDict(BaseModel):
#     role: str
#     content: str
#     result: Any = None
#     tool_call: bool = False
#     tool_args: Optional[Dict[str, Any]] = None
#     create_agent_msg: bool = True
#     node_index: Optional[Tuple[str, str, int]] = None

# class ProductAnalysis(BaseModel):
#     product_name: str
#     analysis: str

# class MarketingStrategy(BaseModel):
#     product_name: str
#     strategy: str

# class WorkflowState(BaseModel):
#     products: List[str]
#     analyses: List[ProductAnalysis] = Field(default_factory=list)
#     strategies: List[MarketingStrategy] = Field(default_factory=list)

# # Define agent functions
# def market_analyst(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As the Lead Market Analyst at a premier digital marketing firm, you specialize in dissecting online business landscapes. Your goal:
#     Conduct amazing analysis of the products and competitors, providing in-depth
#     insights to guide marketing strategies"""

#     for product in state.products:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Analyze the product: {product}"}
#             ]
#         )
        
#         analysis = response.choices[0].message.content
#         state.analyses.append(ProductAnalysis(product_name=product, analysis=analysis))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Analyzed {len(state.products)} products",
#         result=len(state.analyses),
#         create_agent_msg=True
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def marketing_strategist(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """You are the Chief Marketing Strategist at a leading digital marketing agency, known for crafting bespoke strategies that drive success. Your goal:
#     Synthesize amazing insights from product analysis to formulate incredible
#     marketing strategies."""

#     for analysis in state.analyses:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Create a marketing strategy based on this analysis: {analysis.analysis}"}
#             ]
#         )
        
#         strategy = response.choices[0].message.content
#         state.strategies.append(MarketingStrategy(product_name=analysis.product_name, strategy=strategy))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Created strategies for {len(state.analyses)} products",
#         result=len(state.strategies),
#         create_agent_msg=True
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# # Test function
# def test_marketing_workflow():
#     initial_state = WorkflowState(products=["Smartphone", "Laptop", "Smart Watch"])
    
#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")
    
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("MarketAnalyst", "MarketingStrategist")
#     graph.add_edge("MarketingStrategist", "End")

#     print("Executing the marketing workflow...")
#     graph.execute()

#     final_state = WorkflowState(**graph.get_graph_data())
#     print("\nFinal Workflow State:")
#     print(f"Products analyzed: {len(final_state.products)}")
#     print(f"Analyses created: {len(final_state.analyses)}")
#     print(f"Strategies developed: {len(final_state.strategies)}")

#     print("\nDetailed Results:")
#     for product, analysis, strategy in zip(final_state.products, final_state.analyses, final_state.strategies):
#         print(f"\nProduct: {product}")
#         print(f"Analysis summary: {analysis.analysis[:100]}...")
#         print(f"Strategy summary: {strategy.strategy[:100]}...")

#     print("\nAgent Memories:")
#     for agent_id in graph.agent_ids:
#         print(f"\nAgent {agent_id}:")
#         for message in graph.get_agentic_memory(agent_id):
#             print(f"- {message['role']}: {message['content'][:50]}...")

# if __name__ == "__main__":
#     test_marketing_workflow()

# %%
# import openai
# from typing import Any, Dict, List, Optional, Tuple
# from pydantic import BaseModel, Field
# import os

# # Set up OpenAI client
# openapi_key = "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"

# client = openai.OpenAI(api_key=openapi_key)

# class ProductAnalysis(BaseModel):
#     product_name: str
#     analysis: str
#     market_size: str
#     target_audience: str

# class MarketingStrategy(BaseModel):
#     product_name: str
#     strategy: str

# class WorkflowState(BaseModel):
#     products: List[str]
#     analyses: List[ProductAnalysis] = Field(default_factory=list)
#     strategies: List[MarketingStrategy] = Field(default_factory=list)

# # Define agent functions
# def market_analyst(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As the Lead Market Analyst at a premier digital marketing firm, you specialize in dissecting online business landscapes. Your goal:
#     Conduct amazing analysis of the products and competitors, providing in-depth
#     insights to guide marketing strategies. Include market size and target audience in your analysis."""

#     for product in state.products:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Analyze the product: {product}"}
#             ]
#         )
        
#         analysis = response.choices[0].message.content
        
#         # Extract market size and target audience from the analysis
#         market_size = "Large"  # Placeholder, you might want to extract this from the analysis
#         target_audience = "General consumers"  # Placeholder, you might want to extract this from the analysis
        
#         state.analyses.append(ProductAnalysis(
#             product_name=product,
#             analysis=analysis,
#             market_size=market_size,
#             target_audience=target_audience
#         ))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Analyzed {len(state.products)} products",
#         result=len(state.analyses),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def marketing_strategist(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """You are the Chief Marketing Strategist at a leading digital marketing agency, known for crafting bespoke strategies that drive success. Your goal:
#     Synthesize amazing insights from product analysis to formulate incredible
#     marketing strategies."""

#     for analysis in state.analyses:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": system_prompt},
#                 {"role": "user", "content": f"Create a marketing strategy based on this analysis: {analysis.analysis}"}
#             ]
#         )
        
#         strategy = response.choices[0].message.content
#         state.strategies.append(MarketingStrategy(product_name=analysis.product_name, strategy=strategy))

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Created strategies for {len(state.analyses)} products",
#         result=len(state.strategies),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# def niche_market_specialist(graph_data: Dict[str, Any]) -> Dict[str, Any]:
#     state = WorkflowState(**graph_data)
    
#     system_prompt = """As a Niche Market Specialist, your expertise lies in tailoring strategies for products with smaller, highly specific target audiences. Your goal:
#     Refine the existing marketing strategies to better suit niche markets and specialized consumer groups."""

#     for analysis, strategy in zip(state.analyses, state.strategies):
#         if analysis.market_size == "Small" and "niche" in analysis.target_audience.lower():
#             response = client.chat.completions.create(
#                 model="gpt-3.5-turbo",
#                 messages=[
#                     {"role": "system", "content": system_prompt},
#                     {"role": "user", "content": f"Refine this strategy for a niche market:\nProduct: {analysis.product_name}\nAnalysis: {analysis.analysis}\nCurrent Strategy: {strategy.strategy}"}
#                 ]
#             )
            
#             refined_strategy = response.choices[0].message.content
#             strategy.strategy = refined_strategy

#     metahistory = MessageDict(
#         role="assistant",
#         content=f"Refined strategies for niche markets",
#         result=len([s for s in state.strategies if "niche" in s.strategy.lower()]),
#         create_agent_msg=True,
#         tool_call=False
#     )
    
#     return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# # Conditional function for branching
# def is_niche_market(graph_data: Dict[str, Any]) -> bool:
#     state = WorkflowState(**graph_data)
#     return any(analysis.market_size == "Small" and "niche" in analysis.target_audience.lower() for analysis in state.analyses)

# # Test function
# def test_marketing_workflow():
#     initial_state = WorkflowState(products=["Smartphone", "Custom Mechanical Keyboard", "Smart Watch"])
    
#     graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")
    
#     graph.add_node(StartNode())
#     graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
#     graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
#     graph.add_node("NicheMarketSpecialist", niche_market_specialist, is_agent=True)
#     graph.add_node(EndNode())

#     graph.add_edge("Start", "MarketAnalyst")
#     graph.add_edge("MarketAnalyst", "MarketingStrategist")
    
#     # Add branching edge
#     graph.add_branching_edge(
#         "MarketingStrategist",
#         condition=is_niche_market,
#         branches={
#             True: "NicheMarketSpecialist",
#             False: "End"
#         }
#     )
#     graph.add_edge("NicheMarketSpecialist", "End")

#     print("Executing the marketing workflow...")
#     graph.execute()

#     final_state = WorkflowState(**graph.get_graph_data())
#     print("\nFinal Workflow State:")
#     print(f"Products analyzed: {len(final_state.products)}")
#     print(f"Analyses created: {len(final_state.analyses)}")
#     print(f"Strategies developed: {len(final_state.strategies)}")

#     print("\nDetailed Results:")
#     for product, analysis, strategy in zip(final_state.products, final_state.analyses, final_state.strategies):
#         print(f"\nProduct: {product}")
#         print(f"Market Size: {analysis.market_size}")
#         print(f"Target Audience: {analysis.target_audience}")
#         print(f"Analysis summary: {analysis.analysis[:100]}...")
#         print(f"Strategy summary: {strategy.strategy[:100]}...")

#     print("\nAgent Memories:")
#     for agent_id in graph.agent_ids:
#         print(f"\nAgent {agent_id}:")
#         for message in graph.get_agentic_memory(agent_id):
#             print(f"- {message['role']}: {message['content'][:50]}...")

# if __name__ == "__main__":
#     test_marketing_workflow()

# %%
import openai
from typing import Any, Dict, List, Optional, Tuple
from pydantic import BaseModel, Field
import os
# Set up OpenAI client
openapi_key = "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"

client = openai.OpenAI(api_key=openapi_key)

class ProductAnalysis(BaseModel):
    product_name: str
    analysis: str
    market_size: str
    target_audience: str

class MarketingStrategy(BaseModel):
    product_name: str
    strategy: str

class WorkflowState(BaseModel):
    products: List[str]
    analyses: List[ProductAnalysis] = Field(default_factory=list)
    strategies: List[MarketingStrategy] = Field(default_factory=list)

# Define agent functions
def market_analyst(graph_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
    state = WorkflowState(**graph_data)
    
    system_prompt = """As the Lead Market Analyst at a premier digital marketing firm, you specialize in dissecting online business landscapes. Your goal:
    Conduct amazing analysis of the products and competitors, providing in-depth
    insights to guide marketing strategies. Include market size and target audience in your analysis."""

    # Use agentic memory to provide context
    context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])
    
    for product in state.products:
        # Check if analysis for this product already exists in memory
        existing_analysis = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and product in msg['content']), None)
        
        if existing_analysis:
            print(f"Using existing analysis for {product}")
            analysis = existing_analysis['content']
        else:
            print(f"Generating new analysis for {product}")
            response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": f"Previous context:\n{context}\n\nAnalyze the product: {product}"}
                ]
            )
            analysis = response.choices[0].message.content

        # Extract market size and target audience from the analysis
        # For simplicity, we're using placeholder logic here. In a real scenario, you'd want to parse the analysis text.
        market_size = "Large" if "large market" in analysis.lower() else "Small"
        target_audience = "General consumers" if "general" in analysis.lower() else "Niche market"
        
        state.analyses.append(ProductAnalysis(
            product_name=product,
            analysis=analysis,
            market_size=market_size,
            target_audience=target_audience
        ))

    metahistory = MessageDict(
        role="assistant",
        content=f"Analyzed {len(state.products)} products",
        result=len(state.analyses),
        create_agent_msg=True,
        tool_call=False
    )
    
    return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

def marketing_strategist(graph_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
    state = WorkflowState(**graph_data)
    
    system_prompt = """You are the Chief Marketing Strategist at a leading digital marketing agency, known for crafting bespoke strategies that drive success. Your goal:
    Synthesize amazing insights from product analysis to formulate incredible
    marketing strategies."""

    # Use agentic memory to provide context
    context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])

    for analysis in state.analyses:
        # Check if strategy for this product already exists in memory
        existing_strategy = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and analysis.product_name in msg['content']), None)
        
        if existing_strategy:
            print(f"Using existing strategy for {analysis.product_name}")
            strategy = existing_strategy['content']
        else:
            print(f"Generating new strategy for {analysis.product_name}")
            response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": f"Previous context:\n{context}\n\nCreate a marketing strategy based on this analysis: {analysis.analysis}"}
                ]
            )
            strategy = response.choices[0].message.content

        state.strategies.append(MarketingStrategy(product_name=analysis.product_name, strategy=strategy))

    metahistory = MessageDict(
        role="assistant",
        content=f"Created strategies for {len(state.analyses)} products",
        result=len(state.strategies),
        create_agent_msg=True,
        tool_call=False
    )
    
    return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

def niche_market_specialist(graph_data: Dict[str, Any], agentic_memory: List[Dict[str, Any]]) -> Dict[str, Any]:
    state = WorkflowState(**graph_data)
    
    system_prompt = """As a Niche Market Specialist, your expertise lies in tailoring strategies for products with smaller, highly specific target audiences. Your goal:
    Refine the existing marketing strategies to better suit niche markets and specialized consumer groups."""

    # Use agentic memory to provide context
    context = "\n".join([f"{msg['role']}: {msg['content']}" for msg in agentic_memory[-5:]])

    for analysis, strategy in zip(state.analyses, state.strategies):
        if analysis.market_size == "Small" and "niche" in analysis.target_audience.lower():
            # Check if refined strategy for this product already exists in memory
            existing_refined_strategy = next((msg for msg in reversed(agentic_memory) if msg['role'] == 'assistant' and f"Refined strategy for {analysis.product_name}" in msg['content']), None)
            
            if existing_refined_strategy:
                print(f"Using existing refined strategy for {analysis.product_name}")
                refined_strategy = existing_refined_strategy['content']
            else:
                print(f"Generating new refined strategy for {analysis.product_name}")
                response = client.chat.completions.create(
                    model="gpt-3.5-turbo",
                    messages=[
                        {"role": "system", "content": system_prompt},
                        {"role": "user", "content": f"Previous context:\n{context}\n\nRefine this strategy for a niche market:\nProduct: {analysis.product_name}\nAnalysis: {analysis.analysis}\nCurrent Strategy: {strategy.strategy}"}
                    ]
                )
                refined_strategy = response.choices[0].message.content

            strategy.strategy = refined_strategy

    metahistory = MessageDict(
        role="assistant",
        content=f"Refined strategies for niche markets",
        result=len([s for s in state.strategies if "niche" in s.strategy.lower()]),
        create_agent_msg=True,
        tool_call=False
    )
    
    return {"graph_data": state.dict(), "metahistory": metahistory.dict()}

# Conditional function for branching
def is_niche_market(graph_data: Dict[str, Any]) -> bool:
    state = WorkflowState(**graph_data)
    return any(analysis.market_size == "Small" and "niche" in analysis.target_audience.lower() for analysis in state.analyses)

# Test function
def test_marketing_workflow():
    initial_state = WorkflowState(products=["Smartphone", "Custom Mechanical Keyboard", "Smart Watch"])
    
    graph = AgenticGraph(initial_state.dict(), chat_id="marketing_workflow")
    
    graph.add_node(StartNode())
    graph.add_node("MarketAnalyst", market_analyst, is_agent=True)
    graph.add_node("MarketingStrategist", marketing_strategist, is_agent=True)
    graph.add_node("NicheMarketSpecialist", niche_market_specialist, is_agent=True)
    graph.add_node(EndNode())

    graph.add_edge("Start", "MarketAnalyst")
    graph.add_edge("MarketAnalyst", "MarketingStrategist")
    
    # Add branching edge
    graph.add_branching_edge(
        "MarketingStrategist",
        condition=is_niche_market,
        branches={
            True: "NicheMarketSpecialist",
            False: "End"
        }
    )
    graph.add_edge("NicheMarketSpecialist", "End")

    print("Executing the marketing workflow...")
    graph.execute()

    final_state = WorkflowState(**graph.get_graph_data())
    print("\nFinal Workflow State:")
    print(f"Products analyzed: {len(final_state.products)}")
    print(f"Analyses created: {len(final_state.analyses)}")
    print(f"Strategies developed: {len(final_state.strategies)}")

    print("\nDetailed Results:")
    for product, analysis, strategy in zip(final_state.products, final_state.analyses, final_state.strategies):
        print(f"\nProduct: {product}")
        print(f"Market Size: {analysis.market_size}")
        print(f"Target Audience: {analysis.target_audience}")
        print(f"Analysis summary: {analysis.analysis[:100]}...")
        print(f"Strategy summary: {strategy.strategy[:100]}...")

    print("\nAgent Memories:")
    for agent_id in graph.agent_ids:
        print(f"\nAgent {agent_id}:")
        for message in graph.get_agentic_memory(agent_id):
            print(f"- {message['role']}: {message['content'][:50]}...")

    # Run the workflow again to demonstrate memory usage
    print("\nRunning the workflow again to demonstrate memory usage...")
    graph.execute()

    # Print updated agent memories
    print("\nUpdated Agent Memories after second run:")
    for agent_id in graph.agent_ids:
        print(f"\nAgent {agent_id}:")
        for message in graph.get_agentic_memory(agent_id):
            print(f"- {message['role']}: {message['content'][:50]}...")

if __name__ == "__main__":
    test_marketing_workflow()
# Out:
# 2024-08-25 19:08:55,922 - INFO - Starting execution with initial data: {'products': ['Smartphone', 'Custom Mechanical Keyboard', 'Smart Watch'], 'analyses': [], 'strategies': []}
# Executing the marketing workflow...
# Generating new analysis for Smartphone
# 2024-08-25 19:09:02,523 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new analysis for Custom Mechanical Keyboard
# 2024-08-25 19:09:09,793 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new analysis for Smart Watch
# 2024-08-25 19:09:16,617 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new strategy for Smartphone
# 2024-08-25 19:09:22,804 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new strategy for Custom Mechanical Keyboard
# 2024-08-25 19:09:28,247 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new strategy for Smart Watch
# 2024-08-25 19:09:32,437 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new refined strategy for Smartphone
# 2024-08-25 19:09:37,322 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new refined strategy for Custom Mechanical Keyboard
# 2024-08-25 19:09:43,692 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generating new refined strategy for Smart Watch
# 2024-08-25 19:09:49,229 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-08-25 19:09:49,232 - INFO - Execution ended with final data: {'products': ['Smartphone', 'Custom Mechanical Keyboard', 'Smart Watch'], 'analyses': [{'product_name': 'Smartphone', 'analysis': "The smartphone industry is one of the most dynamic and competitive markets in the tech sector, with a wide range of players competing for market share. Smartphones have become an essential part of daily life for billions of people around the world, offering not just communication, but also entertainment, productivity, and utility through a myriad of apps and features.\n\n**Market Size:**\nThe global smartphone market is massive, with over 1.5 billion units sold annually. The market size is expected to continue growing, driven by factors such as increasing digitalization, rising disposable income levels in emerging markets, and the constant innovation in smartphone technology. The market is dominated by key players such as Apple, Samsung, Huawei, Xiaomi, Oppo, and others.\n\n**Target Audience:**\nThe target audience for smartphones is incredibly broad, encompassing consumers of all ages and demographics. However, different brands and models often target specific segments based on factors such as price, features, design, and brand image.\n\n- **Apple:** Known for its premium pricing and high-end features, Apple's iPhones are popular among tech-savvy consumers, professionals, and individuals who prioritize brand status and ecosystem integration.\n\n- **Samsung:** Samsung offers a wide range of smartphones across various price points, appealing to budget-conscious consumers, as well as those looking for high-performance devices with innovative features.\n\n- **Huawei:** Huawei targets a diverse audience with its smartphones, including budget-conscious consumers, photography enthusiasts, and users interested in cutting-edge technology like 5G connectivity.\n\n- **Xiaomi:** Xiaomi is known for offering feature-rich smartphones at competitive prices, making them popular among price-sensitive consumers, value-seekers, and tech enthusiasts.\n\n- **Oppo:** Oppo focuses on design and camera capabilities in its smartphones, appealing to trendy consumers, selfie enthusiasts, and individuals looking for stylish devices.\n\n**Competitive Analysis:**\nCompetition in the smartphone market is intense, with brands constantly innovating to attract and retain customers. Factors such as technology, design, performance, camera quality, battery life, pricing, and brand reputation play crucial roles in shaping competitive dynamics.\n\n- **Apple vs. Samsung:** Apple and Samsung are the two dominant players in the global smartphone market, with fierce competition in the premium segment. Apple's focus on design, ecosystem integration, and brand loyalty competes with Samsung's emphasis on cutting-edge technology, diverse product offerings, and wide distribution network.\n\n- **Huawei vs. Xiaomi:** Huawei and Xiaomi are major players, particularly in the mid-range and budget segments. Huawei's strength lies in its advanced camera technology and 5G capabilities, while Xiaomi's competitive pricing and feature-rich devices appeal to cost-conscious consumers.\n\n- **Oppo vs. Vivo:** Oppo and Vivo, both owned by BBK Electronics, compete in the mid-range and budget segments with a focus on design and camera capabilities. Oppo's emphasis on style and innovation contrasts with Vivo's focus on photography and sleek designs.\n\n**Marketing Strategies:**\nTo succeed in the competitive smartphone market, brands need to differentiate themselves through innovation, marketing, and customer experience. Strategies such as product diversification, strong branding, targeted advertising, strategic partnerships, and after-sales support are crucial for driving sales and brand loyalty.\n\nIn conclusion, the smartphone industry offers immense opportunities for brands to connect with diverse consumer segments by offering a mix of performance, design, features, and pricing. Understanding  ...
# 2024-08-25 19:09:49,233 - INFO - Reached EndNode: End
# 2024-08-25 19:09:49,233 - INFO - Graph execution completed.
# 2024-08-25 19:09:49,234 - INFO - Execution ended with final data: {'products': ['Smartphone', 'Custom Mechanical Keyboard', 'Smart Watch'], 'analyses': [{'product_name': 'Smartphone', 'analysis': "The smartphone industry is one of the most dynamic and competitive markets in the tech sector, with a wide range of players competing for market share. Smartphones have become an essential part of daily life for billions of people around the world, offering not just communication, but also entertainment, productivity, and utility through a myriad of apps and features.\n\n**Market Size:**\nThe global smartphone market is massive, with over 1.5 billion units sold annually. The market size is expected to continue growing, driven by factors such as increasing digitalization, rising disposable income levels in emerging markets, and the constant innovation in smartphone technology. The market is dominated by key players such as Apple, Samsung, Huawei, Xiaomi, Oppo, and others.\n\n**Target Audience:**\nThe target audience for smartphones is incredibly broad, encompassing consumers of all ages and demographics. However, different brands and models often target specific segments based on factors such as price, features, design, and brand image.\n\n- **Apple:** Known for its premium pricing and high-end features, Apple's iPhones are popular among tech-savvy consumers, professionals, and individuals who prioritize brand status and ecosystem integration.\n\n- **Samsung:** Samsung offers a wide range of smartphones across various price points, appealing to budget-conscious consumers, as well as those looking for high-performance devices with innovative features.\n\n- **Huawei:** Huawei targets a diverse audience with its smartphones, including budget-conscious consumers, photography enthusiasts, and users interested in cutting-edge technology like 5G connectivity.\n\n- **Xiaomi:** Xiaomi is known for offering feature-rich smartphones at competitive prices, making them popular among price-sensitive consumers, value-seekers, and tech enthusiasts.\n\n- **Oppo:** Oppo focuses on design and camera capabilities in its smartphones, appealing to trendy consumers, selfie enthusiasts, and individuals looking for stylish devices.\n\n**Competitive Analysis:**\nCompetition in the smartphone market is intense, with brands constantly innovating to attract and retain customers. Factors such as technology, design, performance, camera quality, battery life, pricing, and brand reputation play crucial roles in shaping competitive dynamics.\n\n- **Apple vs. Samsung:** Apple and Samsung are the two dominant players in the global smartphone market, with fierce competition in the premium segment. Apple's focus on design, ecosystem integration, and brand loyalty competes with Samsung's emphasis on cutting-edge technology, diverse product offerings, and wide distribution network.\n\n- **Huawei vs. Xiaomi:** Huawei and Xiaomi are major players, particularly in the mid-range and budget segments. Huawei's strength lies in its advanced camera technology and 5G capabilities, while Xiaomi's competitive pricing and feature-rich devices appeal to cost-conscious consumers.\n\n- **Oppo vs. Vivo:** Oppo and Vivo, both owned by BBK Electronics, compete in the mid-range and budget segments with a focus on design and camera capabilities. Oppo's emphasis on style and innovation contrasts with Vivo's focus on photography and sleek designs.\n\n**Marketing Strategies:**\nTo succeed in the competitive smartphone market, brands need to differentiate themselves through innovation, marketing, and customer experience. Strategies such as product diversification, strong branding, targeted advertising, strategic partnerships, and after-sales support are crucial for driving sales and brand loyalty.\n\nIn conclusion, the smartphone industry offers immense opportunities for brands to connect with diverse consumer segments by offering a mix of performance, design, features, and pricing. Understanding  ...
# 2024-08-25 19:09:49,234 - INFO - Reached EndNode: End
# 2024-08-25 19:09:49,235 - INFO - Graph execution completed.
# Final Workflow State:
# Products analyzed: 3
# Analyses created: 3
# Strategies developed: 3
#
# Detailed Results:
#
# Product: Smartphone
# Market Size: Small
# Target Audience: Niche market
# Analysis summary: The smartphone industry is one of the most dynamic and competitive markets in the tech sector, with ...
# Strategy summary: Refined Strategy for Niche Market:
#
# Product: Smartphone
# Niche Market: Eco-conscious Consumers
#
# Analy...
#
# Product: Custom Mechanical Keyboard
# Market Size: Small
# Target Audience: Niche market
# Analysis summary: Product: Custom Mechanical Keyboard
#
# Market Size:
# The market for custom mechanical keyboards has bee...
# Strategy summary: Refined Strategy for Niche Market:
#
# 1. **Customization for Niche Preferences**:
#    Rather than offer...
#
# Product: Smart Watch
# Market Size: Small
# Target Audience: Niche market
# Analysis summary: Product: Smart Watch
#
# Market Size:
# The smartwatch market has been growing rapidly over the past few ...
# Strategy summary: Refined Marketing Strategies for Niche Markets:
#
# 1. Customized Features for Specific Niche Audiences...
#
# Agent Memories:
#
# Agent a50d188d-6429-4a85-aabc-ff153ff4fe52:
# - assistant: Analyzed 3 products...
#
# Agent a22b9233-ee6d-427e-ad48-2ee8af8d8ed8:
# - assistant: Created strategies for 3 products...
#
# Agent b79b3577-7806-47c6-bd09-417d673f202e:
# - assistant: Refined strategies for niche markets...
#
# Running the workflow again to demonstrate memory usage...
#
# Updated Agent Memories after second run:
#
# Agent a50d188d-6429-4a85-aabc-ff153ff4fe52:
# - assistant: Analyzed 3 products...
#
# Agent a22b9233-ee6d-427e-ad48-2ee8af8d8ed8:
# - assistant: Created strategies for 3 products...
#
# Agent b79b3577-7806-47c6-bd09-417d673f202e:
# - assistant: Refined strategies for niche markets...
